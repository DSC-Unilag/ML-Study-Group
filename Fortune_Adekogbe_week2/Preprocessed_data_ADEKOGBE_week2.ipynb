# %%
import pandas as pd
file = 'preprocessed_data.csv'
Data = pd.read_csv(file)
Data.head()
# Out:
#   Winner  title_bout  no_of_rounds  B_current_lose_streak  \
# 0    Red        True             5                    0.0
# 1    Red        True             5                    0.0
# 2    Red       False             3                    0.0
# 3   Blue       False             3                    0.0
# 4   Blue       False             3                    0.0
#
#    B_current_win_streak  B_draw  B_avg_BODY_att  B_avg_BODY_landed  \
# 0                   4.0     0.0        9.200000           6.000000
# 1                   3.0     0.0       14.600000           9.100000
# 2                   3.0     0.0       15.354839          11.322581
# 3                   4.0     0.0       17.000000          14.000000
# 4                   1.0     0.0       17.000000          14.500000
#
#    B_avg_CLINCH_att  B_avg_CLINCH_landed  ...  \
# 0          0.200000             0.000000  ...
# 1         11.800000             7.300000  ...
# 2          6.741935             4.387097  ...
# ...

# %%
Data.tail()
# Out:
#      Winner  title_bout  no_of_rounds  B_current_lose_streak  \
# 3587    Red       False             1                    0.0
# 3588    Red       False             1                    0.0
# 3589    Red        True             1                    0.0
# 3590    Red       False             1                    0.0
# 3591    Red       False             1                    0.0
#
#       B_current_win_streak  B_draw  B_avg_BODY_att  B_avg_BODY_landed  \
# 3587                   1.0     0.0             1.0                1.0
# 3588                   1.0     0.0             0.0                0.0
# 3589                   2.0     0.0             0.5                0.5
# 3590                   1.0     0.0             0.0                0.0
# 3591                   1.0     0.0             4.0                3.0
#
#       B_avg_CLINCH_att  B_avg_CLINCH_landed  ...  \
# 3587               0.0                  0.0  ...
# 3588               1.0                  1.0  ...
# ...

# %%
print(Data.columns)
# Out:
# Index(['Winner', 'title_bout', 'no_of_rounds', 'B_current_lose_streak',
#        'B_current_win_streak', 'B_draw', 'B_avg_BODY_att', 'B_avg_BODY_landed',
#        'B_avg_CLINCH_att', 'B_avg_CLINCH_landed',
#        ...
#        'weight_class_Women's Strawweight', 'B_Stance_Open Stance',
#        'B_Stance_Orthodox', 'B_Stance_Sideways', 'B_Stance_Southpaw',
#        'B_Stance_Switch', 'R_Stance_Open Stance', 'R_Stance_Orthodox',
#        'R_Stance_Southpaw', 'R_Stance_Switch'],
#       dtype='object', length=160)

# %%
Data.shape
# Out:
# (3592, 160)

# %%
index_4 =Data.iloc[3,:]
print(index_4)
# Out:
# Winner                    Blue
# title_bout               False
# no_of_rounds                 3
# B_current_lose_streak        0
# B_current_win_streak         4
#                          ...
# B_Stance_Switch              1
# R_Stance_Open Stance         0
# R_Stance_Orthodox            1
# R_Stance_Southpaw            0
# R_Stance_Switch              0
# Name: 3, Length: 160, dtype: object

# %%
Data.describe()
# Out:
#        no_of_rounds  B_current_lose_streak  B_current_win_streak  B_draw  \
# count   3592.000000            3592.000000           3592.000000  3592.0
# mean       3.196548               0.560412              1.126114     0.0
# std        0.664834               0.790660              1.385555     0.0
# min        1.000000               0.000000              0.000000     0.0
# 25%        3.000000               0.000000              0.000000     0.0
# 50%        3.000000               0.000000              1.000000     0.0
# 75%        3.000000               1.000000              2.000000     0.0
# max        5.000000               6.000000             12.000000     0.0
#
#        B_avg_BODY_att  B_avg_BODY_landed  B_avg_CLINCH_att  \
# count     3592.000000        3592.000000       3592.000000
# mean         8.800322           6.158010          8.308673
# std          7.099821           5.077738          7.518370
# min          0.000000           0.000000          0.000000
# ...

# %%
#Based off the statistics from the table above, the maximum values are far greater than the mean which 
#means that outliers exist.

# %%
Data.dropna(axis = 0)
Data.dtypes
# Out:
# Winner                    object
# title_bout                  bool
# no_of_rounds               int64
# B_current_lose_streak    float64
# B_current_win_streak     float64
#                           ...
# B_Stance_Switch            int64
# R_Stance_Open Stance       int64
# R_Stance_Orthodox          int64
# R_Stance_Southpaw          int64
# R_Stance_Switch            int64
# Length: 160, dtype: object

# %%
pd.get_dummies(Data['title_bout'])
# Out:
#       False  True
# 0         0      1
# 1         0      1
# 2         1      0
# 3         1      0
# 4         1      0
# ...     ...    ...
# 3587      1      0
# 3588      1      0
# 3589      0      1
# 3590      1      0
# 3591      1      0
#
# [3592 rows x 2 columns]

# %%
x = pd.get_dummies(Data['Winner']).iloc[:,0]
y = pd.get_dummies(Data['Winner']).iloc[:,1]
data.insert(2,'Blue_winners',x)
data.insert(2,'Red_winners',y)

# %%
title_true = pd.get_dummies(Data['title_bout']).iloc[:,0]
title_false = pd.get_dummies(Data['title_bout']).iloc[:,1]
data.insert(4,'False_title_bout',x)
data.insert(4,'True_title_bout',y)

# %%
Data.drop('Winner',axis=1,inplace=True)
Data.drop('title_bout',axis=1,inplace=True)

# %%
data.head()
# Out:
#    Red_winners  Blue_winners  True_title_bout  False_title_bout  no_of_rounds  \
# 0            1             0                1                 0             5
# 1            1             0                1                 0             5
# 2            1             0                1                 0             3
# 3            0             1                0                 1             3
# 4            0             1                0                 1             3
#
#    B_current_lose_streak  B_current_win_streak  B_draw  B_avg_BODY_att  \
# 0                    0.0                   4.0     0.0        9.200000
# 1                    0.0                   3.0     0.0       14.600000
# 2                    0.0                   3.0     0.0       15.354839
# 3                    0.0                   4.0     0.0       17.000000
# 4                    0.0                   1.0     0.0       17.000000
#
#    B_avg_BODY_landed  ...  weight_class_Women's Strawweight  \
# ...

# %%
Data.corr()
# Out:
#                        no_of_rounds  B_current_lose_streak  \
# no_of_rounds               1.000000              -0.107887
# B_current_lose_streak     -0.107887               1.000000
# B_current_win_streak       0.302900              -0.576231
# B_draw                          NaN                    NaN
# B_avg_BODY_att             0.080438              -0.037919
# ...                             ...                    ...
# B_Stance_Switch           -0.008138              -0.021871
# R_Stance_Open Stance      -0.017118               0.044399
# R_Stance_Orthodox          0.002547               0.004473
# R_Stance_Southpaw          0.010488              -0.025241
# R_Stance_Switch           -0.026754               0.035534
#
#                        B_current_win_streak  B_draw  B_avg_BODY_att  \
# no_of_rounds                       0.302900     NaN        0.080438
# B_current_lose_streak             -0.576231     NaN       -0.037919
# ...

# %%
Data.to_csv('Preprocessed_data_ADEKOGBE_week2.csv')
