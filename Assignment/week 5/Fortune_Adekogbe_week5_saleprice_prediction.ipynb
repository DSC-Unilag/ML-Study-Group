# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_df.shape
# Out:
# (1460, 81)

# %%
[i for i in train_df.columns if train_df[i].count() <1201]
# Out:
# ['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']

# %%
corr=train_df.corr()
corr
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
[i for i in train_df.columns if train_df[i].count() <1460]
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
test_df.shape
# Out:
# (1459, 80)

# %%
[i for i in test_df.columns if test_df[i].count() <test_df.shape[0]]
# Out:
# ['MSZoning',
#  'LotFrontage',
#  'Alley',
#  'Utilities',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageCars',
#  'GarageArea',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType']

# %%
train_df['Fence'].value_counts()
# Out:
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: Fence, dtype: int64

# %%
train_df['Alley'].fillna('None',inplace=True)
test_df['Alley'].fillna('None',inplace=True)

# %%
train_df['FireplaceQu'].fillna('None',inplace=True)
test_df['FireplaceQu'].fillna('None',inplace=True)

# %%
train_df['PoolQC'].fillna('None',inplace=True)
test_df['PoolQC'].fillna('None',inplace=True)

# %%
train_df['Fence'].fillna('None',inplace=True)
test_df['Fence'].fillna('None',inplace=True)

# %%
train_df['MiscFeature'].fillna('None',inplace=True)
test_df['MiscFeature'].fillna('None',inplace=True)

# %%
dd = list(filter(lambda i:train_df[i].count()<1460,train_df.columns))

# %%
train_df[dd]
# Out:
#       LotFrontage MasVnrType  MasVnrArea BsmtQual BsmtCond BsmtExposure  \
# 0            65.0    BrkFace       196.0       Gd       TA           No
# 1            80.0       None         0.0       Gd       TA           Gd
# 2            68.0    BrkFace       162.0       Gd       TA           Mn
# 3            60.0       None         0.0       TA       Gd           No
# 4            84.0    BrkFace       350.0       Gd       TA           Av
# ...           ...        ...         ...      ...      ...          ...
# 1455         62.0       None         0.0       Gd       TA           No
# 1456         85.0      Stone       119.0       Gd       TA           No
# 1457         66.0       None         0.0       TA       Gd           No
# 1458         68.0       None         0.0       TA       TA           Mn
# 1459         75.0       None         0.0       TA       TA           No
#
#      BsmtFinType1 BsmtFinType2 Electrical GarageType  GarageYrBlt  \
# ...

# %%
for data in [train_df,test_df]:
    data['GarageYrBlt'] = 2020 - data['GarageYrBlt']
    data['GarageYrBlt'].fillna(15.0,inplace=True)
    data['GarageYrBlt']=data['GarageYrBlt'].astype('int64')

# %%
tuple(test_df['GarageYrBlt'].mode())[0]
# Out:
# 15.0

# %%
for data in [train_df,test_df]:
    for i in ['LotFrontage','MasVnrArea']:
        x = data[i].mean()
        data[i].fillna(x,inplace=True)

# %%
[i for i in list(filter(lambda i:test_df[i].count()<1459,test_df.columns)) if i not in dummable]
# Out:
# ['MSZoning',
#  'Utilities',
#  'Exterior1st',
#  'Exterior2nd',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'KitchenQual',
#  'Functional',
#  'GarageCars',
#  'GarageArea',
#  'SaleType']

# %%
test_df[['MSZoning',
 'Utilities',
 'Exterior1st',
 'Exterior2nd',
 'BsmtFinSF1',
 'BsmtFinSF2',
 'BsmtUnfSF',
 'TotalBsmtSF',
 'BsmtFullBath',
 'BsmtHalfBath',
 'KitchenQual',
 'Functional',
 'GarageCars',
 'GarageArea',
 'SaleType']].count()
# Out:
# MSZoning        1459
# Utilities       1459
# Exterior1st     1459
# Exterior2nd     1459
# BsmtFinSF1      1459
# BsmtFinSF2      1459
# BsmtUnfSF       1459
# TotalBsmtSF     1459
# BsmtFullBath    1459
# BsmtHalfBath    1459
# KitchenQual     1459
# Functional      1459
# GarageCars      1459
# GarageArea      1459
# SaleType        1459
# dtype: int64

# %%
for i in ['MSZoning', 'Utilities', 'Exterior1st', 'Exterior2nd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
 'BsmtFullBath', 'BsmtHalfBath', 'KitchenQual', 'Functional', 'GarageCars', 'GarageArea', 'SaleType']:
    x = test_df[i].mode()[0]
    test_df[i].fillna(x,inplace=True)

# %%
plt.figure(figsize=(20,20)) 
sns.heatmap(corr)

# %%
switch= dict(train_df.dtypes)

# %%
objs = [k for k,v in switch.items() if v=='object']

# %%
objs
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
len(objs)
# Out:
# 43

# %%
dum_train = pd.get_dummies(train_df[objs])
dum_train['Id']=train_df['Id']

# %%
train_data = pd.merge(train_df,dum_train,on ='Id')

# %%
train_data.drop(objs,axis=1,inplace=True)

# %%
dum_test = pd.get_dummies(test_df[objs])
dum_test['Id']=test_df['Id']

# %%
test_data = pd.merge(test_df,dum_test,on ='Id')

# %%
test_data.drop(objs,axis=1,inplace=True)

# %%
[i for i in train_df.columns if i not in test_df.columns]
# Out:
# ['SalePrice']

# %%
Y_train = train_data['SalePrice']
X_train = train_data.drop('SalePrice',axis=1)

# %%
X_test = test_data

# %%
overly = [i for i in X_train.columns if i not in X_test.columns]

# %%
X_train.drop(overly,axis=1,inplace=True)

# %%
from sklearn.linear_model import LinearRegression
LinReg = LinearRegression()
LinReg.fit(X_train,Y_trainX_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_pred=LinReg.predict(X_test)

# %%
submission = pd.read_csv('sample_submission.csv')

# %%
submission['SalePrice'] = Y_pred

# %%
submission.to_csv('solution.csv',index=False)

# %%
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
Input = [('scale',StandardScaler()), ('polynomial', PolynomialFeatures(degree=2)),('pca',PCA(n_components=10)),('model', LinearRegression())]

# %%
pipe = Pipeline(Input)
pipe.fit(X_train,Y_train) #trains
# Out:
# Pipeline(memory=None,
#          steps=[('scale',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('polynomial',
#                  PolynomialFeatures(degree=2, include_bias=True,
#                                     interaction_only=False, order='C')),
#                 ('pca',
#                  PCA(copy=True, iterated_power='auto', n_components=10,
#                      random_state=None, svd_solver='auto', tol=0.0,
#                      whiten=False)),
#                 ('model',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %%
Yhat = pipe.predict(X_test) #predicts

# %%
submission01 = pd.read_csv('sample_submission.csv')
submission01['SalePrice'] = Yhat
submission01.to_csv('solution01.csv',index=False)
