# %%
import pandas as pd
fp = "C:/Users/MY PC/Desktop/raw_fighter_details.csv"
df1 = pd.read_csv(fp)
print(df1)
# Out:
#                 fighter_name  Height    Weight Reach    Stance           DOB
# 0                 AJ Fonseca   5' 4"  145 lbs.   NaN       NaN           NaN
# 1                AJ Matthews  5' 11"  185 lbs.   NaN       NaN           NaN
# 2                   AJ McKee  5' 10"  145 lbs.   NaN       NaN           NaN
# 3                  AJ Siscoe   5' 7"  135 lbs.   NaN       NaN           NaN
# 4                 Aalon Cruz   6' 0"  145 lbs.   NaN       NaN           NaN
# 5                Aaron Brink   6' 3"  205 lbs.   NaN  Orthodox  Nov 12, 1974
# 6                  Aaron Ely   5' 8"  135 lbs.   NaN       NaN  Mar 18, 1989
# 7              Aaron Jeffery   6' 2"  185 lbs.   NaN       NaN  Nov 14, 1992
# 8            Aaron Lanfranco     NaN  155 lbs.   NaN       NaN  Aug 26, 1986
# 9               Aaron Miller   5' 9"  145 lbs.   NaN       NaN           NaN
# 10            Aaron Phillips   5' 9"  135 lbs.   70"  Southpaw  Aug 05, 1989
# ...

# %%
fp1 = "C:/Users/MY PC/Desktop/preprocessed_data.csv"
df2 = pd.read_csv(fp1)
print(df2)
# Out:
#      Winner  title_bout  no_of_rounds  B_current_lose_streak  \
# 0       Red        True             5                    0.0
# 1       Red        True             5                    0.0
# 2       Red       False             3                    0.0
# 3      Blue       False             3                    0.0
# 4      Blue       False             3                    0.0
# 5       Red       False             3                    0.0
# 6       Red       False             3                    0.0
# 7      Blue       False             3                    1.0
# 8      Blue       False             3                    0.0
# 9       Red       False             3                    0.0
# 10     Blue       False             3                    1.0
# 11      Red       False             3                    0.0
# 12     Blue       False             5                    1.0
# 13     Blue       False             3                    0.0
# ...

# %%
#print the first row of df1
df1[:1]
# Out:
#   fighter_name Height    Weight Reach Stance  DOB
# 0   AJ Fonseca  5' 4"  145 lbs.   NaN    NaN  NaN

# %%
#print the last 5 rows of df1
df1.tail()
# Out:
#           fighter_name  Height    Weight Reach    Stance           DOB
# 3308     Zelim Imadaev   6' 0"  170 lbs.   76"  Orthodox  Jan 25, 1995
# 3309      Zhang Lipeng  5' 11"  155 lbs.   71"  Southpaw  Mar 10, 1990
# 3310     Zoila Frausto   5' 4"  135 lbs.   NaN  Orthodox           NaN
# 3311        Zu Anyanwu   6' 1"  251 lbs.   77"  Orthodox  Aug 05, 1981
# 3312  Zubaira Tukhugov   5' 8"  145 lbs.   68"  Orthodox  Jan 15, 1991

# %%
#print the first row of df2
df2[:1]
# Out:
#   Winner  title_bout  no_of_rounds  B_current_lose_streak  \
# 0    Red        True             5                    0.0
#
#    B_current_win_streak  B_draw  B_avg_BODY_att  B_avg_BODY_landed  \
# 0                   4.0     0.0             9.2                6.0
#
#    B_avg_CLINCH_att  B_avg_CLINCH_landed  ...  \
# 0               0.2                  0.0  ...
#
#    weight_class_Women's Strawweight  B_Stance_Open Stance  B_Stance_Orthodox  \
# 0                                 0                     0                  1
#
#    B_Stance_Sideways  B_Stance_Southpaw  B_Stance_Switch  \
# 0                  0                  0                0
#
#    R_Stance_Open Stance  R_Stance_Orthodox  R_Stance_Southpaw  R_Stance_Switch
# 0                     0                  1                  0                0
#
# [1 rows x 160 columns]

# %%
#print the last five rows of df2
df2.tail()
# Out:
#      Winner  title_bout  no_of_rounds  B_current_lose_streak  \
# 3587    Red       False             1                    0.0
# 3588    Red       False             1                    0.0
# 3589    Red        True             1                    0.0
# 3590    Red       False             1                    0.0
# 3591    Red       False             1                    0.0
#
#       B_current_win_streak  B_draw  B_avg_BODY_att  B_avg_BODY_landed  \
# 3587                   1.0     0.0             1.0                1.0
# 3588                   1.0     0.0             0.0                0.0
# 3589                   2.0     0.0             0.5                0.5
# 3590                   1.0     0.0             0.0                0.0
# 3591                   1.0     0.0             4.0                3.0
#
#       B_avg_CLINCH_att  B_avg_CLINCH_landed  ...  \
# 3587               0.0                  0.0  ...
# 3588               1.0                  1.0  ...
# ...

# %%
#print columns of df1
for col in df1.columns:
    print(col)
# Out:
# fighter_name
# Height
# Weight
# Reach
# Stance
# DOB

# %%
#print columns of df2
for col in df2.columns:
    print(col)
# Out:
# Winner
# title_bout
# no_of_rounds
# B_current_lose_streak
# B_current_win_streak
# B_draw
# B_avg_BODY_att
# B_avg_BODY_landed
# B_avg_CLINCH_att
# B_avg_CLINCH_landed
# B_avg_DISTANCE_att
# B_avg_DISTANCE_landed
# B_avg_GROUND_att
# B_avg_GROUND_landed
# B_avg_HEAD_att
# B_avg_HEAD_landed
# B_avg_KD
# B_avg_LEG_att
# B_avg_LEG_landed
# B_avg_PASS
# B_avg_REV
# B_avg_SIG_STR_att
# B_avg_SIG_STR_landed
# B_avg_SIG_STR_pct
# B_avg_SUB_ATT
# B_avg_TD_att
# B_avg_TD_landed
# B_avg_TD_pct
# B_avg_TOTAL_STR_att
# B_avg_TOTAL_STR_landed
# B_longest_win_streak
# B_losses
# B_avg_opp_BODY_att
# B_avg_opp_BODY_landed
# B_avg_opp_CLINCH_att
# B_avg_opp_CLINCH_landed
# B_avg_opp_DISTANCE_att
# B_avg_opp_DISTANCE_landed
# B_avg_opp_GROUND_att
# B_avg_opp_GROUND_landed
# B_avg_opp_HEAD_att
# B_avg_opp_HEAD_landed
# B_avg_opp_KD
# B_avg_opp_LEG_att
# B_avg_opp_LEG_landed
# B_avg_opp_PASS
# B_avg_opp_REV
# B_avg_opp_SIG_STR_att
# B_avg_opp_SIG_STR_landed
# B_avg_opp_SIG_STR_pct
# B_avg_opp_SUB_ATT
# ...

# %%
#print the shape of the df1
df1.shape
# Out:
# (3313, 6)

# %%
#print the shape of the df1
df2.shape
# Out:
# (3592, 160)

# %%
#Get the 4th row of df1 and save it in a variable called index_4
index_4 = df1.iloc[3]
index_4
# Out:
# fighter_name    AJ Siscoe
# Height              5' 7"
# Weight           135 lbs.
# Reach                 NaN
# Stance                NaN
# DOB                   NaN
# Name: 3, dtype: object

# %%
#Get the 4th row of df2 and save it in a variable called index_14
index_14 = df2.iloc[3]
index_14
# Out:
# Winner                                  Blue
# title_bout                             False
# no_of_rounds                               3
# B_current_lose_streak                      0
# B_current_win_streak                       4
# B_draw                                     0
# B_avg_BODY_att                            17
# B_avg_BODY_landed                         14
# B_avg_CLINCH_att                       13.75
# B_avg_CLINCH_landed                       11
# B_avg_DISTANCE_att                     109.5
# B_avg_DISTANCE_landed                  48.75
# B_avg_GROUND_att                          13
# B_avg_GROUND_landed                     10.5
# B_avg_HEAD_att                        116.25
# B_avg_HEAD_landed                      53.75
# B_avg_KD                                 0.5
# B_avg_LEG_att                              3
# B_avg_LEG_landed                         2.5
# B_avg_PASS                               0.5
# B_avg_REV                               0.25
# ...

# %%
#estimate the statistics of df1
df1.describe(include = 'all')
# Out:
#            fighter_name Height    Weight Reach    Stance           DOB
# count              3313   3050      3238  1569      2439          2573
# unique             3313     27       108    25         5          2217
# top     Dave Courchaine  6' 0"  170 lbs.   72"  Orthodox  Aug 08, 1988
# freq                  1    389       522   159      1913             4

# %%
#estimate the statistics of df2
df2.describe(include = 'all')
# Out:
#        Winner title_bout  no_of_rounds  B_current_lose_streak  \
# count    3592       3592   3592.000000            3592.000000
# unique      2          2           NaN                    NaN
# top       Red      False           NaN                    NaN
# freq     2380       3337           NaN                    NaN
# mean      NaN        NaN      3.196548               0.560412
# std       NaN        NaN      0.664834               0.790660
# min       NaN        NaN      1.000000               0.000000
# 25%       NaN        NaN      3.000000               0.000000
# 50%       NaN        NaN      3.000000               0.000000
# 75%       NaN        NaN      3.000000               1.000000
# max       NaN        NaN      5.000000               6.000000
#
#         B_current_win_streak  B_draw  B_avg_BODY_att  B_avg_BODY_landed  \
# count            3592.000000  3592.0     3592.000000        3592.000000
# unique                   NaN     NaN             NaN                NaN
# ...

# %%
#drop or fill missing values of Height column in df1 with suitable value
df1.dropna(subset = ["Height"], axis = 0)
# Out:
#                 fighter_name  Height    Weight Reach    Stance           DOB
# 5                Aaron Brink   6' 3"  205 lbs.   NaN  Orthodox  Nov 12, 1974
# 6                  Aaron Ely   5' 8"  135 lbs.   NaN       NaN  Mar 18, 1989
# 7              Aaron Jeffery   6' 2"  185 lbs.   NaN       NaN  Nov 14, 1992
# 8            Aaron Lanfranco     NaN  155 lbs.   NaN       NaN  Aug 26, 1986
# 10            Aaron Phillips   5' 9"  135 lbs.   70"  Southpaw  Aug 05, 1989
# 11               Aaron Riley   5' 8"  155 lbs.   69"  Southpaw  Dec 09, 1980
# 12                Aaron Rosa   6' 4"  205 lbs.   78"  Orthodox  May 28, 1983
# 13             Aaron Simpson   6' 0"  170 lbs.   73"  Orthodox  Jul 20, 1974
# 16           Aaron Wilkinson  5' 10"  155 lbs.   NaN       NaN  Jan 31, 1987
# 17      Abdul Razak Alhassan  5' 10"  170 lbs.   73"  Orthodox  Aug 11, 1985
# 18        Abdul-Kerim Edilov   6' 2"  205 lbs.   78"  Orthodox  Nov 25, 1991
# ...

# %%
#drop or fill missing values of Reach column in df1 with suitable value
df1.dropna(subset = ["Reach"], axis = 0)
# Out:
#                fighter_name  Height    Weight Reach    Stance           DOB
# 10           Aaron Phillips   5' 9"  135 lbs.   70"  Southpaw  Aug 05, 1989
# 11              Aaron Riley   5' 8"  155 lbs.   69"  Southpaw  Dec 09, 1980
# 12               Aaron Rosa   6' 4"  205 lbs.   78"  Orthodox  May 28, 1983
# 13            Aaron Simpson   6' 0"  170 lbs.   73"  Orthodox  Jul 20, 1974
# 17     Abdul Razak Alhassan  5' 10"  170 lbs.   73"  Orthodox  Aug 11, 1985
# 18       Abdul-Kerim Edilov   6' 2"  205 lbs.   78"  Orthodox  Nov 25, 1991
# 20            Abel Trujillo   5' 8"  155 lbs.   70"  Orthodox  Sep 18, 1983
# 21           Abner Lloveras  5' 11"  155 lbs.   71"       NaN  Sep 04, 1982
# 24              Abu Azaitar   5' 9"  185 lbs.   76"  Orthodox  Mar 10, 1986
# 26             Adam Antolin   5' 5"  125 lbs.   63"  Orthodox  Feb 28, 1982
# 27               Adam Cella   6' 2"  170 lbs.   78"       NaN  Jun 26, 1985
# ...

# %%
#drop or fill missing values of Stance column in df1 with suitable value
df1.dropna(subset = ["Stance"], axis = 0)
# Out:
#                fighter_name  Height    Weight Reach    Stance           DOB
# 5               Aaron Brink   6' 3"  205 lbs.   NaN  Orthodox  Nov 12, 1974
# 10           Aaron Phillips   5' 9"  135 lbs.   70"  Southpaw  Aug 05, 1989
# 11              Aaron Riley   5' 8"  155 lbs.   69"  Southpaw  Dec 09, 1980
# 12               Aaron Rosa   6' 4"  205 lbs.   78"  Orthodox  May 28, 1983
# 13            Aaron Simpson   6' 0"  170 lbs.   73"  Orthodox  Jul 20, 1974
# 17     Abdul Razak Alhassan  5' 10"  170 lbs.   73"  Orthodox  Aug 11, 1985
# 18       Abdul-Kerim Edilov   6' 2"  205 lbs.   78"  Orthodox  Nov 25, 1991
# 19              Abel Cullum   5' 7"  139 lbs.   NaN  Orthodox  Apr 21, 1987
# 20            Abel Trujillo   5' 8"  155 lbs.   70"  Orthodox  Sep 18, 1983
# 22          Abongo Humphrey  5' 11"  205 lbs.   NaN  Orthodox           NaN
# 24              Abu Azaitar   5' 9"  185 lbs.   76"  Orthodox  Mar 10, 1986
# ...

# %%
#drop or fill missing values of DOB column in df1 with suitable value
df1.dropna(subset = ["DOB"], axis = 0)
# Out:
#                 fighter_name  Height    Weight Reach    Stance           DOB
# 5                Aaron Brink   6' 3"  205 lbs.   NaN  Orthodox  Nov 12, 1974
# 6                  Aaron Ely   5' 8"  135 lbs.   NaN       NaN  Mar 18, 1989
# 7              Aaron Jeffery   6' 2"  185 lbs.   NaN       NaN  Nov 14, 1992
# 8            Aaron Lanfranco     NaN  155 lbs.   NaN       NaN  Aug 26, 1986
# 10            Aaron Phillips   5' 9"  135 lbs.   70"  Southpaw  Aug 05, 1989
# 11               Aaron Riley   5' 8"  155 lbs.   69"  Southpaw  Dec 09, 1980
# 12                Aaron Rosa   6' 4"  205 lbs.   78"  Orthodox  May 28, 1983
# 13             Aaron Simpson   6' 0"  170 lbs.   73"  Orthodox  Jul 20, 1974
# 16           Aaron Wilkinson  5' 10"  155 lbs.   NaN       NaN  Jan 31, 1987
# 17      Abdul Razak Alhassan  5' 10"  170 lbs.   73"  Orthodox  Aug 11, 1985
# 18        Abdul-Kerim Edilov   6' 2"  205 lbs.   78"  Orthodox  Nov 25, 1991
# ...

# %%
#check for correlation of the columns in df1
df1[['fighter_name', 'Weight', 'Height', 'Reach', 'Stance', 'DOB']].corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#check for correlation of the columns in df2
df2.corr(method = 'pearson')
# Out:
#                                     title_bout  no_of_rounds  \
# title_bout                            1.000000      0.637445
# no_of_rounds                          0.637445      1.000000
# B_current_lose_streak                -0.143853     -0.107887
# B_current_win_streak                  0.316009      0.302900
# B_draw                                     NaN           NaN
# B_avg_BODY_att                       -0.006543      0.080438
# B_avg_BODY_landed                     0.006808      0.088073
# B_avg_CLINCH_att                      0.003882      0.045107
# B_avg_CLINCH_landed                   0.007960      0.049887
# B_avg_DISTANCE_att                   -0.019275      0.085152
# B_avg_DISTANCE_landed                -0.007171      0.104060
# B_avg_GROUND_att                      0.096193      0.092675
# B_avg_GROUND_landed                   0.097666      0.093213
# B_avg_HEAD_att                        0.004701      0.102065
# ...

# %%
df1.to_csv('processed_data_week2.ipynb')

# %%
df2.to_csv('processed_data1_week2.ipynb')
