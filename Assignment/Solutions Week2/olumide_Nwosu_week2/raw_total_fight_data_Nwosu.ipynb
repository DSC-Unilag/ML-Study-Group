# %%
import pandas as pd

# %%
df = pd.read_csv("raw_total_fight_data.csv", sep=';')

# %%
# printing first 5 rows
for i in range(5):
    print("Row {}\n{}\n\n".format(i+1, df.iloc[i]))
    
# printing last five rows
index = dataframe.shape[0]-5
for i in range(5):
    print("Row {}\n{}\n".format(index, df.iloc[index]))
    index -=- 1
# Out:
# Row 1
# R_fighter                         Henry Cejudo
# B_fighter                        Marlon Moraes
# R_KD                                         0
# B_KD                                         0
# R_SIG_STR.                           90 of 171
# B_SIG_STR.                           57 of 119
# R_SIG_STR_pct                              52%
# B_SIG_STR_pct                              47%
# R_TOTAL_STR.                         99 of 182
# B_TOTAL_STR.                         59 of 121
# R_TD                                    1 of 4
# B_TD                                    0 of 2
# R_TD_pct                                   25%
# B_TD_pct                                    0%
# R_SUB_ATT                                    1
# B_SUB_ATT                                    0
# R_PASS                                       1
# B_PASS                                       0
# R_REV                                        0
# B_REV                                        0
# ...

# %%
print(df.columns)
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR.', 'B_SIG_STR.',
#        'R_SIG_STR_pct', 'B_SIG_STR_pct', 'R_TOTAL_STR.', 'B_TOTAL_STR.',
#        'R_TD', 'B_TD', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_PASS', 'B_PASS', 'R_REV', 'B_REV', 'R_HEAD', 'B_HEAD', 'R_BODY',
#        'B_BODY', 'R_LEG', 'B_LEG', 'R_DISTANCE', 'B_DISTANCE', 'R_CLINCH',
#        'B_CLINCH', 'R_GROUND', 'B_GROUND', 'win_by', 'last_round',
#        'last_round_time', 'Format', 'Referee', 'date', 'location',
#        'Fight_type', 'Winner'],
#       dtype='object')

# %%
print(df.shape)
# Out:
# (5144, 41)

# %%
index_4 = df.iloc[3]

# %%
df.describe()
# Out:
#               R_KD         B_KD    R_SUB_ATT    B_SUB_ATT       R_PASS  \
# count  5144.000000  5144.000000  5144.000000  5144.000000  5144.000000
# mean      0.252333     0.180404     0.510886     0.361003     1.401439
# std       0.523318     0.459646     0.948139     0.809795     2.301587
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     1.000000     0.000000     2.000000
# max       5.000000     4.000000    10.000000     7.000000    26.000000
#
#             B_PASS        R_REV        B_REV   last_round
# count  5144.000000  5144.000000  5144.000000  5144.000000
# mean      0.831260     0.141719     0.134137     2.288297
# std       1.651515     0.427448     0.416798     1.003732
# min       0.000000     0.000000     0.000000     1.000000
# ...

# %%
df = df.fillna(axis=0, method='bfill')
df
# Out:
#                   R_fighter            B_fighter  R_KD  B_KD  R_SIG_STR.  \
# 0              Henry Cejudo        Marlon Moraes     0     0   90 of 171
# 1      Valentina Shevchenko          Jessica Eye     1     0     8 of 11
# 2             Tony Ferguson       Donald Cerrone     0     0  104 of 200
# 3             Jimmie Rivera             Petr Yan     0     2   73 of 192
# 4               Tai Tuivasa        Blagoy Ivanov     0     1   64 of 144
# 5            Tatiana Suarez        Nina Ansaroff     0     0   75 of 142
# 6         Aljamain Sterling         Pedro Munhoz     0     0  174 of 349
# 7     Karolina Kowalkiewicz         Alexa Grasso     0     0   90 of 232
# 8             Ricardo Lamas        Calvin Kattar     0     1    12 of 29
# 9               Yan Xiaonan          Angela Hill     0     0   94 of 249
# 10              Bevon Lewis       Darren Stewart     0     0    31 of 84
# 11           Eddie Wineland       Grigorii Popov     2     0   74 of 171
# ...

# %%
df[df.columns].corr()
# Out:
#                 R_KD      B_KD  R_SUB_ATT  B_SUB_ATT    R_PASS    B_PASS  \
# R_KD        1.000000 -0.110068  -0.108992  -0.093408 -0.113336 -0.125981
# B_KD       -0.110068  1.000000  -0.095970  -0.037095 -0.106515 -0.026231
# R_SUB_ATT  -0.108992 -0.095970   1.000000   0.046162  0.336716  0.066240
# B_SUB_ATT  -0.093408 -0.037095   0.046162   1.000000  0.132128  0.255787
# R_PASS     -0.113336 -0.106515   0.336716   0.132128  1.000000 -0.054455
# B_PASS     -0.125981 -0.026231   0.066240   0.255787 -0.054455  1.000000
# R_REV      -0.073842 -0.046033   0.227679   0.215045  0.204033  0.298298
# B_REV      -0.070521 -0.037023   0.170480   0.218857  0.267956  0.234291
# last_round -0.164803 -0.046165   0.015192   0.106363  0.225454  0.209167
#
#                R_REV     B_REV  last_round
# R_KD       -0.073842 -0.070521   -0.164803
# B_KD       -0.046033 -0.037023   -0.046165
# R_SUB_ATT   0.227679  0.170480    0.015192
# B_SUB_ATT   0.215045  0.218857    0.106363
# ...

# %%
csvFile = df.to_csv("processed_data2_week2.csv")
