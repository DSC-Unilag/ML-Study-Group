# %%
import numpy as np
import pandas as pd
import matplotlib.pyploy as plt
import seaborn as sns

url = "C:/Users/Akorede/Desktop/ufcdata/preprocessed_data.csv"

df = pd.read_csv(url)

#preprocessed data

# %%
#print the first and last five rows of the dataset

df.head(5)
# Out:
#   Winner  title_bout  no_of_rounds  B_current_lose_streak  \
# 0    Red        True             5                    0.0
# 1    Red        True             5                    0.0
# 2    Red       False             3                    0.0
# 3   Blue       False             3                    0.0
# 4   Blue       False             3                    0.0
#
#    B_current_win_streak  B_draw  B_avg_BODY_att  B_avg_BODY_landed  \
# 0                   4.0     0.0        9.200000           6.000000
# 1                   3.0     0.0       14.600000           9.100000
# 2                   3.0     0.0       15.354839          11.322581
# 3                   4.0     0.0       17.000000          14.000000
# 4                   1.0     0.0       17.000000          14.500000
#
#    B_avg_CLINCH_att  B_avg_CLINCH_landed       ...         \
# 0          0.200000             0.000000       ...
# 1         11.800000             7.300000       ...
# ...

# %%
df.tail(5)
# Out:
#      Winner  title_bout  no_of_rounds  B_current_lose_streak  \
# 3587    Red       False             1                    0.0
# 3588    Red       False             1                    0.0
# 3589    Red        True             1                    0.0
# 3590    Red       False             1                    0.0
# 3591    Red       False             1                    0.0
#
#       B_current_win_streak  B_draw  B_avg_BODY_att  B_avg_BODY_landed  \
# 3587                   1.0     0.0             1.0                1.0
# 3588                   1.0     0.0             0.0                0.0
# 3589                   2.0     0.0             0.5                0.5
# 3590                   1.0     0.0             0.0                0.0
# 3591                   1.0     0.0             4.0                3.0
#
#       B_avg_CLINCH_att  B_avg_CLINCH_landed       ...         \
# 3587               0.0                  0.0       ...
# 3588               1.0                  1.0       ...
# ...

# %%
#print the columns of the dataset
print(df.columns)
# Out:
# Index(['Winner', 'title_bout', 'no_of_rounds', 'B_current_lose_streak',
#        'B_current_win_streak', 'B_draw', 'B_avg_BODY_att', 'B_avg_BODY_landed',
#        'B_avg_CLINCH_att', 'B_avg_CLINCH_landed',
#        ...
#        'weight_class_Women's Strawweight', 'B_Stance_Open Stance',
#        'B_Stance_Orthodox', 'B_Stance_Sideways', 'B_Stance_Southpaw',
#        'B_Stance_Switch', 'R_Stance_Open Stance', 'R_Stance_Orthodox',
#        'R_Stance_Southpaw', 'R_Stance_Switch'],
#       dtype='object', length=160)

# %%
#print the shape of the dataset
print(df.shape)
# Out:
# (3592, 160)

# %%
# forth row
index_4 = df.iloc[3:4]
index_4
# Out:
#   Winner  title_bout  no_of_rounds  B_current_lose_streak  \
# 3   Blue       False             3                    0.0
#
#    B_current_win_streak  B_draw  B_avg_BODY_att  B_avg_BODY_landed  \
# 3                   4.0     0.0            17.0               14.0
#
#    B_avg_CLINCH_att  B_avg_CLINCH_landed       ...         \
# 3             13.75                 11.0       ...
#
#    weight_class_Women's Strawweight  B_Stance_Open Stance  B_Stance_Orthodox  \
# 3                                 0                     0                  0
#
#    B_Stance_Sideways  B_Stance_Southpaw  B_Stance_Switch  \
# 3                  0                  0                1
#
#    R_Stance_Open Stance  R_Stance_Orthodox  R_Stance_Southpaw  R_Stance_Switch
# 3                     0                  1                  0                0
#
# [1 rows x 160 columns]

# %%
df.describe(include = "all")
# Out:
#        Winner title_bout  no_of_rounds  B_current_lose_streak  \
# count    3592       3592   3592.000000            3592.000000
# unique      2          2           NaN                    NaN
# top       Red      False           NaN                    NaN
# freq     2380       3337           NaN                    NaN
# mean      NaN        NaN      3.196548               0.560412
# std       NaN        NaN      0.664834               0.790660
# min       NaN        NaN      1.000000               0.000000
# 25%       NaN        NaN      3.000000               0.000000
# 50%       NaN        NaN      3.000000               0.000000
# 75%       NaN        NaN      3.000000               1.000000
# max       NaN        NaN      5.000000               6.000000
#
#         B_current_win_streak  B_draw  B_avg_BODY_att  B_avg_BODY_landed  \
# count            3592.000000  3592.0     3592.000000        3592.000000
# unique                   NaN     NaN             NaN                NaN
# ...

# %%
df.describe()
# Out:
#        no_of_rounds  B_current_lose_streak  B_current_win_streak  B_draw  \
# count   3592.000000            3592.000000           3592.000000  3592.0
# mean       3.196548               0.560412              1.126114     0.0
# std        0.664834               0.790660              1.385555     0.0
# min        1.000000               0.000000              0.000000     0.0
# 25%        3.000000               0.000000              0.000000     0.0
# 50%        3.000000               0.000000              1.000000     0.0
# 75%        3.000000               1.000000              2.000000     0.0
# max        5.000000               6.000000             12.000000     0.0
#
#        B_avg_BODY_att  B_avg_BODY_landed  B_avg_CLINCH_att  \
# count     3592.000000        3592.000000       3592.000000
# mean         8.800322           6.158010          8.308673
# std          7.099821           5.077738          7.518370
# min          0.000000           0.000000          0.000000
# ...

# %%
df.drop("B_draw", axis = 1, inplace = True)

# %%
corr_preprocessed = df.corr()
corr_preprocessed
# Out:
#                                     title_bout  no_of_rounds  \
# title_bout                            1.000000      0.637445
# no_of_rounds                          0.637445      1.000000
# B_current_lose_streak                -0.143853     -0.107887
# B_current_win_streak                  0.316009      0.302900
# B_avg_BODY_att                       -0.006543      0.080438
# B_avg_BODY_landed                     0.006808      0.088073
# B_avg_CLINCH_att                      0.003882      0.045107
# B_avg_CLINCH_landed                   0.007960      0.049887
# B_avg_DISTANCE_att                   -0.019275      0.085152
# B_avg_DISTANCE_landed                -0.007171      0.104060
# B_avg_GROUND_att                      0.096193      0.092675
# B_avg_GROUND_landed                   0.097666      0.093213
# B_avg_HEAD_att                        0.004701      0.102065
# B_avg_HEAD_landed                     0.038746      0.131298
# ...

# %%
df.to_csv("C:/Users/Akorede/Desktop/ufcdata/Akorede_Aboaba_week2/preprocessed_data.csv")

# %%
#raw_fighter_details.csv
url1 = "C:/Users/Akorede/Desktop/ufcdata/raw_fighter_details.csv"

df1 = pd.read_csv(url1)

# %%
#print the first and last five rows of the dataset

df1.head(5)
# Out:
#   fighter_name  Height    Weight Reach Stance  DOB
# 0   AJ Fonseca   5' 4"  145 lbs.   NaN    NaN  NaN
# 1  AJ Matthews  5' 11"  185 lbs.   NaN    NaN  NaN
# 2     AJ McKee  5' 10"  145 lbs.   NaN    NaN  NaN
# 3    AJ Siscoe   5' 7"  135 lbs.   NaN    NaN  NaN
# 4   Aalon Cruz   6' 0"  145 lbs.   NaN    NaN  NaN

# %%
df1.tail(5)
# Out:
#           fighter_name  Height    Weight Reach    Stance           DOB
# 3308     Zelim Imadaev   6' 0"  170 lbs.   76"  Orthodox  Jan 25, 1995
# 3309      Zhang Lipeng  5' 11"  155 lbs.   71"  Southpaw  Mar 10, 1990
# 3310     Zoila Frausto   5' 4"  135 lbs.   NaN  Orthodox           NaN
# 3311        Zu Anyanwu   6' 1"  251 lbs.   77"  Orthodox  Aug 05, 1981
# 3312  Zubaira Tukhugov   5' 8"  145 lbs.   68"  Orthodox  Jan 15, 1991

# %%
#print the columns of the dataset
print(df1.columns)
# Out:
# Index(['fighter_name', 'Height', 'Weight', 'Reach', 'Stance', 'DOB'], dtype='object')

# %%
#print the shape of the dataset
print(df1.shape)
# Out:
# (3313, 6)

# %%
# forth row
index_4 = df1.iloc[3:4]
index_4
# Out:
#   fighter_name Height    Weight Reach Stance  DOB
# 3    AJ Siscoe  5' 7"  135 lbs.   NaN    NaN  NaN

# %%
df1.describe()
# Out:
#        fighter_name Height    Weight Reach    Stance           DOB
# count          3313   3050      3238  1569      2439          2573
# unique         3313     27       108    25         5          2217
# top      Koji Oishi  6' 0"  170 lbs.   72"  Orthodox  Aug 08, 1988
# freq              1    389       522   159      1913             4

# %%
df1.fillna(0)
# Out:
#                fighter_name  Height    Weight Reach    Stance           DOB
# 0            Aaron Phillips   5' 9"  135 lbs.   70"  Southpaw  Aug 05, 1989
# 1               Aaron Riley   5' 8"  155 lbs.   69"  Southpaw  Dec 09, 1980
# 2                Aaron Rosa   6' 4"  205 lbs.   78"  Orthodox  May 28, 1983
# 3             Aaron Simpson   6' 0"  170 lbs.   73"  Orthodox  Jul 20, 1974
# 4      Abdul Razak Alhassan  5' 10"  170 lbs.   73"  Orthodox  Aug 11, 1985
# 5        Abdul-Kerim Edilov   6' 2"  205 lbs.   78"  Orthodox  Nov 25, 1991
# 6             Abel Trujillo   5' 8"  155 lbs.   70"  Orthodox  Sep 18, 1983
# 7               Abu Azaitar   5' 9"  185 lbs.   76"  Orthodox  Mar 10, 1986
# 8              Adam Antolin   5' 5"  125 lbs.   63"  Orthodox  Feb 28, 1982
# 9               Adam Hunter   6' 1"  185 lbs.   73"  Orthodox  Oct 16, 1983
# 10            Adam Milstead   6' 3"  205 lbs.   76"  Orthodox  Jul 03, 1987
# ...

# %%
corr_rfd = df1.corr()
corr_rfd
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.to_csv("C:/Users/Akorede/Desktop/ufcdata/Akorede_Aboaba_week2/raw_fighter_details.csv")
